# %% [markdown]
# # Getting Started

# %%
# import sys
import csv
import pandas as pd

DEBUGGING = False
DATA_DIR  = '../data/'
DATA_FILE = 'house-prices.csv'


#--
# MAIN
#--

#-get data from a file
try:
    df = pd.read_csv( DATA_DIR + DATA_FILE, na_filter=False )
except IOError as iox:
    print('there was an I/O error trying to open the data file: ' + str( iox ))
    sys.exit()
#-get and size of raw data set
N = len( df.columns )
M = len( df.values )

#-print columns
if DEBUGGING:
    print('INPUT FILE = ' + DATA_DIR + DATA_FILE)
    print('number of attributes = ' + str( N ))
    print('number of instances = ' + str( M ))
    for ( i, c, t ) in zip( range( N ), df.columns, df.dtypes ):
        print('{} - {} ({})'.format( i, c, t ))
print(df.values)
print(df["Price"][3])
df.values[3][1]
# Out:
# [[1 114300 1790 ... 2 'No' 'East']
#  [2 114200 2030 ... 3 'No' 'East']
#  [3 114800 1740 ... 1 'No' 'East']
#  ...
#  [126 113500 2070 ... 2 'No' 'North']
#  [127 149900 2020 ... 1 'No' 'West']
#  [128 124600 2250 ... 4 'No' 'North']]
# 94700
# 94700

# %% [markdown]
# # Build a Distance Matrix

# %%
import sys
import csv
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

def dist_square( v0, v1 ):
    d = math.pow(v0-v1,2)
    return d

def dist_nominal( v0, v1 ):
    if ( v0 == v1 ):
        d = 0.0
    else:
        d = 1.0
    return d

def dist_instance_euclidean( df, X0, X1 ):
    N = len(df.columns)
    d = 0.0
    for i in range(1,N):
        if(df.dtypes[i] == 'object'):
            d += dist_nominal(df.values[X0][i],df.values[X1][i])
        else:
            d += dist_square(df.values[X0][i],df.values[X1][i])
    d = math.sqrt( d )
    return d

def dist_instance_manhattan(df,X0,X1):
    N = len(df.columns)
    d= 0.0
    for i in range(1,N):
        if(df.dtypes[i] == 'object'):
            d += dist_nominal(df.values[X0][i],df.values[X1][i])
        else:
            d += abs(df.values[X0][i] - df.values[X1][i])
    return d

# %%
#-compute distances between instances
dist_mesh_euclidean = np.zeros((M,M))
dist_mesh_manhattan = np.zeros((M,M))
for i in range(M):
    for j in range(i+1,M):
        dist_mesh_euclidean[i][j] = dist_instance_euclidean(df,i,j)
        dist_mesh_euclidean[j][i] = dist_mesh_euclidean[i][j] 
        dist_mesh_manhattan[i][j] = dist_instance_manhattan(df,i,j)
        dist_mesh_manhattan[j][i] = dist_mesh_manhattan[i][j]
print('Euclidean: mean distance = {} ({}), minimum distance = {}, maximum distance = {}'.format( np.mean( dist_mesh_euclidean ), np.std( dist_mesh_euclidean ), np.min( dist_mesh_euclidean ), np.max( dist_mesh_euclidean )))
print('Manhattan: mean distance = {} ({}), minimum distance = {}, maximum distance = {}'.format( np.mean( dist_mesh_manhattan ), np.std( dist_mesh_manhattan ), np.min( dist_mesh_manhattan ), np.max( dist_mesh_manhattan )))
# Out:
# Euclidean: mean distance = 30055.349130814982 (23007.526884197912), minimum distance = 0.0, maximum distance = 142102.4827615619
# Manhattan: mean distance = 30291.340942382812 (23057.33673526354), minimum distance = 0.0, maximum distance = 142945.0

# %%
x0_range = np.arange(M)
x1_range = np.arange(M)
x0_mesh, x1_mesh = np.meshgrid( x0_range, x1_range )

plt.figure()
plt.set_cmap( 'Reds' )
plt.pcolormesh( x0_mesh, x1_mesh, dist_mesh_euclidean, shading='auto' )
plt.title( 'Euclidean distances' )

plt.show()
plt.close()

x0 = np.arange(M)
x1 = np.arange(M)
x0_mesh, x1_mesh = np.meshgrid(x0_range,x1_range)

plt.figure()
plt.set_cmap("Greens")
plt.pcolormesh(x0_mesh,x1_mesh,dist_mesh_manhattan,shading="auto")
plt.title("Manhattan distances")
plt.show()
plt.close()

# %% [markdown]
# # Build an Instance-Based Model

# %%
import sys
import csv
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

def dist_square( v0, v1 ):
    d = math.pow((v0-v1),2)
    return d

def dist_nominal( v0, v1 ):
    d = 0.0
    if(v0 == v1):
        d = 1.0
    else:
        d = 0.0
    return d

def dist_instance_euclidean(df0,X0, df):
    N = len(df0.columns)
    d= 0.0
    for i in range(2,N):
        if(df0.dtypes[i] == 'object'):
            d += dist_nominal(df0[df0.columns[i]][X0],df[df0.columns[i]][0])
        else:
            d += dist_square(df0[df0.columns[i]][X0],df[df0.columns[i]][0])
    d = math.sqrt( d )
    return d

def dist_instance_manhattan(df0,X0,df):
    N = len(df0.columns)
    d = 0.0
    for i in range(2,N):
        if(df0.dtypes[i] == 'object'):
            d += dist_nominal(df0[df0.columns[i]][X0],df[df0.columns[i]][0])
        else:
            d += abs(df0[df0.columns[i]][X0] - df[df0.columns[i]][0])     
    return d 

X = df.values   
M = len(X)
#number of neighbours
K = 5

Home = {'HomeID': [-999],"Price":[-999],'SqFt':[2050],"Bedrooms":[2],"Bathrooms":[1],
        "Offers" :[2],"Brick":['No'],'Neighborhood':['East']}

df_test = pd.DataFrame.from_dict(Home)
dist_euclidean = np.zeros(M)

# for euclidean
#look for the neighbour
for i in range(M):
    dist_euclidean[i] = dist_instance_euclidean( df, i,df_test )

sorted_dist = np.argsort( dist_euclidean )   

# get the total and avg price 
prices = 0.0
for i in range(K):
    prices += df["Price"][sorted_dist[i]]
prices /= K
print('average price = $' + str( prices ))

#for manhattan
#look for the neighbour
dist_manhattan = np.zeros(M)

for i in range(M):
    dist_manhattan[i] = dist_instance_manhattan(df,i,df_test)
sorted_dist1 = np.argsort(dist_manhattan)

#get the total and avg price  
price = 0.0
for i in range(K):
    price += df["Price"][sorted_dist1[i]]
price /= K
print('average price = ${}' .format(price) )
# Out:
# average price = $134220.0
# average price = $146680.0

# %% [markdown]
# # Numeric Variation

# %%
import sys
import csv
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt


DEBUGGING = False
DATA_DIR  = '../data/'
DATA_FILE = 'house-prices.csv'
PLOTS_DIR = '../plots/'

ENCODE_BRICK = { 'No' : 0 , 'Yes' : 1 }
ENCODE_HOOD  = { 'East' : 0, 'North' : 90, 'West' : 180, 'South' : 270 }

Home = {'HomeID': [-999],"Price":[-999],'SqFt':[2050],"Bedrooms":[2],"Bathrooms":[1],
        "Offers" :[2],"Brick":['No'],'Neighborhood':['East']}
K = 5

def dist_square( v0, v1 ):
    d = math.pow((v0-v1),2)
    return d

def dist_instance_euclidean(X0,X1,N):
    
    d= 0.0
    for i in range(1,N):
        d += dist_square(X0[i],X1[i])
    d = math.sqrt( d )
    return d

def dist_instance_manhattan(X0,X1,N):

    d = 0.0
    for i in range(1,N):
        d += abs(X0[i] - X1[i])     
    return d 


M = len(df.values)
N = len(df.columns)

#encode the attr
X = np.zeros((M,N))

for i in range(M):
    for j in range(N):
        if(df.columns[j] == "Brick"):
            X[i][j] = ENCODE_BRICK[df[df.columns[j]][i]]
        elif(df.columns[j] == 'Neighborhood'):
            X[i][j] = ENCODE_HOOD[df.values[i][j]]
        else:
            X[i][j] = df.values[i][j]
#compute the distance matrix
dist_mesh_euclidean = np.zeros((M,M))
dist_mesh_manhattan = np.zeros((M,M))
for i in range(M):
    for j in range(i+1,M):
        dist_mesh_euclidean[i][j] = dist_instance_euclidean(X[i],X[j],N)
        dist_mesh_euclidean[j][i] = dist_mesh_euclidean[i][j]
        dist_mesh_manhattan[i][j] = dist_instance_manhattan(X[i],X[j],N)
        dist_mesh_manhattan[j][i] = dist_mesh_manhattan[i][j]
# build the pcolormesh for the euclidean
X0_range = np.arange(M)
X1_range = np.arange(M)
X0_mesh, X1_mesh = np.meshgrid(X0_range,X1_range)

plt.figure()
plt.set_cmap("Blues")
plt.pcolormesh(X0_mesh, X1_mesh,dist_mesh_euclidean,shading="auto")
plt.title("Euclidean distances")
plt.show()
plt.close()
# build the pcolormesh for the manhattan
X0_range = np.arange(M)
X1_range = np.arange(M)
X0_mesh, X1_mesh = np.meshgrid(X0_range,X1_range)

plt.figure()
plt.set_cmap("Blues")
plt.pcolormesh(X0_mesh, X1_mesh,dist_mesh_euclidean,shading="auto")
plt.title("Manhattan distances")
plt.show()
plt.close()
# #compute the K neighbour
# dist_euclidean = np.zeros(M)
# df_test = pd.DataFrame.from_dict(Home)
# for i in range(M):
#     dist_euclidean[i] = dist_instance_euclidean(df,i,df_test)
# sorted_args = np.argsort(dist_euclidean)

# # get the price
# price = 0.0
# for i in range (K):
#     price += df["Price"][sorted_args[i]]
# price /= K
# print('average price = $' + str( price ))

# %%
Home = {'HomeID': [-999],"Price":[-999],'SqFt':[2050],"Bedrooms":[2],"Bathrooms":[1],
        "Offers" :[2],"Brick":['No'],'Neighborhood':['East']}
df_test = pd.DataFrame.from_dict(Home)
df_test
a = [10,3,4,2,5]
arr = np.array(a)
sorted_dist = np.argsort( arr)  
sorted_dist
# Out:
# array([3, 1, 2, 4, 0], dtype=int64)

# %%
import sys
import csv
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt


DEBUGGING = False
DATA_DIR  = '../data/'
DATA_FILE = 'house-prices.csv'
PLOTS_DIR = '../plots/'

ENCODE_BRICK = { 'No' : 0 , 'Yes' : 1 }
ENCODE_HOOD  = { 'East' : 0, 'North' : 90, 'West' : 180, 'South' : 270 }


#--
# dist_square()
# This function returns the squared difference between two scalar
# arguments, v0 and v1.
#--
def dist_square( v0, v1 ):
    d = math.pow( v0 - v1, 2 )
    return d


#--
# dist_instance_euclidean()
# This function returns the Euclidean distance between two instances,
# X0 and X1, each of which is an array of scalar attribute values.
# Note that the first attribute (HomeID) is ignored.
#--
def dist_instance_euclidean( X0, X1, N ):
    d = 0.0
    for i in range( 1, N ):
        d += dist_square( X0[i], X1[i] ) 
    d = math.sqrt( d )
    return d


#--
# dist_instance_manhattan()
# This function returns the Manhattan distance between two instances,
# X0 and X1, each of which is an array of scalar attribute values.
# Note that the first attribute (HomeID) is ignored.
#--
def dist_instance_manhattan( X0, X1, N ):
    d = 0.0
    for i in range( 1, N ):
        d += abs( X0[i] - X1[i] ) 
    return d


#--
# MAIN
#--

#-get data from a file
try:
    df = pd.read_csv( DATA_DIR + DATA_FILE, na_filter=False )
    
except IOError as iox:
    print('there was an I/O error trying to open the data file: ' + str( iox ))
    sys.exit()

#-get size of raw data set
N = len( df.columns )
M = len( df.values )

#-print columns
if DEBUGGING:
    print('INPUT FILE = ' + DATA_DIR + DATA_FILE)
    print('number of attributes = ' + str( N ))
    print('number of instances = ' + str( M ))
    for ( i, c, t ) in zip( range( N ), df.columns, df.dtypes ):
        print('{} - {} ({})'.format( i, c, t ))
    print('possible values of Brick = ', set( df['Brick'] ))
    print('possible values of Neighborhood = ', set( df['Neighborhood'] ))

#-encode all variables as numeric
X = np.zeros(( M, N ))
print(np.shape( X ))
for j in range( M ):
    for i in range( N ):
        if ( df.columns[i] == 'Brick' ):
            X[j][i] = ENCODE_BRICK[ df.values[j][i] ]
        elif ( df.columns[i] == 'Neighborhood' ):
            X[j][i] = ENCODE_HOOD[ df.values[j][i] ]
        else:
            X[j][i] = df.values[j][i]

#-compute distances between instances
dist_mesh_euclidean = np.zeros(( M, M ))
dist_mesh_manhattan = np.zeros(( M, M ))
for j0 in range( M ):
    for j1 in range( j0+1, M ):
        dist = dist_instance_euclidean( X[j0], X[j1], N )
        dist_mesh_euclidean[j0][j1] = dist
        dist_mesh_euclidean[j1][j0] = dist
        dist = dist_instance_manhattan( X[j0], X[j1], N )
        dist_mesh_manhattan[j0][j1] = dist
        dist_mesh_manhattan[j1][j0] = dist
dist_mesh_manhattan
dist_mesh_euclidean

x_range = np.arange(M)
y_range = np.arange(M)
x_mesh, y_mesh = np.meshgrid(x_range,y_range)

plt.figure()
plt.set_cmap("Greens")
plt.pcolormesh(x_mesh,y_mesh,dist_mesh_euclidean,shading= 'auto')
plt.title("Euclidean distances")
plt.show()
plt.close()

plt.figure()
plt.set_cmap("Reds")
plt.pcolormesh(x_mesh,y_mesh,dist_mesh_manhattan,shading='auto')
plt.title("Manhattan distances")
plt.show()
plt.close()
# Out:
# (128, 8)

# %%
home = np.zeros( N )
Home = {'HomeID': [-999],"Price":[-999],'SqFt':[2050],"Bedrooms":[2],"Bathrooms":[1],
        "Offers" :[2],"Brick":['No'],'Neighborhood':['East']}
df_home = pd.DataFrame.from_dict(Home)
for i in range (N):
    if(df_home.columns[i] == 'Brick'):
        home[i] = ENCODE_BRICK[Home[df_home.columns[i]][0]]
    elif(df_home.columns[i] == 'Neighborhood'):
        home[i] = ENCODE_HOOD[Home[df_home.columns[i]][0]]
    else:
        home[i] = Home[df_home.columns[i]][0]

dist_euclidean = np.zeros(M)
dist_manhattan = np.zeros(M)

for i in range(M):
    dist_euclidean[i] = dist_instance_euclidean(home,X[i],N)
    dist_manhattan[i] = dist_instance_manhattan(home,X[i],N)

    
K=5
print('{} closest according to Euclidean distance:'.format( K ))
sorted_list = np.argsort(dist_euclidean)
price = 0.0
for i in range(K):
    print('({}) HomeID={} distance={}'.format( i, X[sorted_dist[i]][0], dist_euclidean[sorted_dist[i]] ))
    price += df["Price"][sorted_list[i]]
price /= K
print('average price = $' + str( price ))

sorted_list = np.argsort(dist_manhattan)
price = 0.0
for i in range(K):
    print('({}) HomeID={} distance={}'.format( i, X[sorted_dist[i]][0], dist_euclidean[sorted_dist[i]] ))
    price += X[sorted_list[i]][1]
price /= K
print('average price = $' + str( price ))
# Out:
# 5 closest according to Euclidean distance:
# (0) HomeID=74.0 distance=10.246950765959598
# (1) HomeID=123.0 distance=10.14889156509222
# (2) HomeID=68.0 distance=10.44030650891055
# (3) HomeID=2.0 distance=20.149441679609886
# (4) HomeID=11.0 distance=20.09975124224178
# average price = $133820.0
# (0) HomeID=74.0 distance=10.246950765959598
# (1) HomeID=123.0 distance=10.14889156509222
# (2) HomeID=68.0 distance=10.44030650891055
# (3) HomeID=2.0 distance=20.149441679609886
# (4) HomeID=11.0 distance=20.09975124224178
# average price = $133820.0

# %% [markdown]
# # Build a K-Nearest Neighbours Model

# %%
import sys
import csv
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import sklearn.neighbors as neighbors

DATA_DIR  = '../data/'
DATA_FILE = 'house-prices.csv'
PLOTS_DIR = '../plots/'

ENCODE_BRICK = {"No" : 0,'Yes':1}
ENCODE_HOOD = {"East" : 0, "North" : 90, "West": 180,"South" : 270}

try:
    df = pd.read_csv( DATA_DIR + DATA_FILE, na_filter=False)
except IOError as iox:
    print('there was an I/O error trying to open the data file: ' + str( iox ))
    sys.exit()
    
M = len(df.values)
N = len(df.columns)

# build X
X = np.zeros((M,N-1))
for i in range(M):
    for j in range(1,N):
        if(df.columns[j] == "Brick"):
            X[i][j-1] = ENCODE_BRICK[df.values[i][j]]
        elif(df.columns[j] == 'Neighborhood'):
            X[i][j-1] = ENCODE_HOOD[df.values[i][j]]
        else:
            X[i][j-1] = df.values[i][j]

#-compute K nearest neighbours
K = M
nn_euclidean = neighbors.NearestNeighbors(n_neighbors= K ,algorithm='kd_tree',metric='euclidean')
nn_manhattan = neighbors.NearestNeighbors(n_neighbors= K, algorithm='kd_tree',metric='manhattan')
nn_euclidean.fit(X)
nn_manhattan.fit(X)
dist_euc, ind_euc = nn_euclidean.kneighbors( X, return_distance=True )
dist_man, ind_man = nn_manhattan.kneighbors( X, return_distance=True )
# print(np.shape( dist_euc ))
# print(np.shape( ind_euc ))


dist_mesh_euclidean = np.zeros(( M, M ))
dist_mesh_manhattan = np.zeros(( M, M ))
for i in range(M):
    for j in range(M):
        dist_mesh_euclidean[i][ind_euc[i][j]] = dist_euc[i][j]
        dist_mesh_manhattan[i][ind_man[i][j]] = dist_man[i][j]
print('Euclidean: mean distance = {} ({}), minimum distance = {}, maximum distance = {}'.format( np.mean( dist_mesh_euclidean ), np.std( dist_mesh_euclidean ), np.min( dist_mesh_euclidean ), np.max( dist_mesh_euclidean )))
print('Manhattan: mean distance = {} ({}), minimum distance = {}, maximum distance = {}'.format( np.mean( dist_mesh_manhattan ), np.std( dist_mesh_manhattan ), np.min( dist_mesh_manhattan ), np.max( dist_mesh_manhattan )))

x_range  = np.arange(M)
y_range = np.arange(M)
x_mesh, y_mesh = np.meshgrid(x_range,y_range)

plt.figure()
plt.set_cmap("Reds")
plt.pcolormesh(x_mesh,y_mesh,dist_mesh_euclidean,shading='auto')
plt.title("Euclidean")
plt.show()
plt.close()

plt.figure()
plt.set_cmap("Greens")
plt.pcolormesh(x_mesh,y_mesh,dist_mesh_manhattan,shading='auto')
plt.title("Manhattan")
plt.show()
plt.close()
# Out:
# Euclidean: mean distance = 30055.83403493584 (23007.12368279778), minimum distance = 0.0, maximum distance = 142102.5112585981
# Manhattan: mean distance = 30369.843017578125 (23075.888085295082), minimum distance = 0.0, maximum distance = 143034.0

# %%
MY_HOUSE = { 'Price' : 0, 'SqFt' : 2050, 'Bedrooms' : 2, 'Bathrooms' : 1, 'Offers' : 2, 'Brick' : 'No', 'Neighborhood' : 'East' }
K = 5

M = len(df.values)
N = len(df.columns)

X = np.zeros((M,N-2))
for i in range(M):
    for j in range(2,N):
        if ( df.columns[j] == 'Brick' ):
            X[i][j-2] = ENCODE_BRICK[ df.values[i][j] ]
        elif ( df.columns[j] == 'Neighborhood' ):
            X[i][j-2] = ENCODE_HOOD[ df.values[i][j] ]
        else:
            X[i][j-2] = df.values[i][j]
home = np.zeros(N-2)

# print(home.shape)
# print(home)
# print(np.shape( home ))
# print(np.shape( X ))
for i in range(2,N):
    if(df.columns[i] == 'Brick'):
        home[i-2] = ENCODE_BRICK[MY_HOUSE[df.columns[i]]]
    elif(df.columns[i] == 'Neighborhood'):
        home[i-2] = ENCODE_HOOD[MY_HOUSE[df.columns[i]]]
    else:
        home[i-2] = MY_HOUSE[df.columns[i]]
home = home.reshape(1,6)
print(home.shape)
print(home)
print(np.shape( home ))
nn_euclidean = neighbors.NearestNeighbors( n_neighbors=K, algorithm='kd_tree', metric='euclidean' )
nn_manhattan = neighbors.NearestNeighbors( n_neighbors=K, algorithm='kd_tree', metric='manhattan' )

nn_euclidean.fit(X)
nn_manhattan.fit(X)

dist_euc, ind_euc  = nn_euclidean.kneighbors(home, return_distance = True)
dist_man, ind_man = nn_manhattan.kneighbors(home,return_distance = True)

print('{} closest according to Euclidean distance:'.format( K ))
prices = 0.0
for i in range(K):
    print('({}) HomeID={} distance={}'.format( i, df.values[ind_euc[0][i]][0],dist_euc[0][i] ))
    prices += df['Price'][ind_euc[0][i]]
prices /= K
print('average price = $' + str( prices ))

print('{} closest according to Manhattan distance:'.format( K ))
prices = 0.0
for i in range(K):
    print('({}) HomeID={} distance={}'.format( i, df.values[ind_man[0][i]][0],dist_man[0][i] ))
    prices += df['Price'][ind_man[0][i]]
prices /= K
print('average price = $' + str( prices ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a65a98ac2a2f> in <module>
#       2 K = 5
#       3
# ----> 4 M = len(df.values)
#       5 N = len(df.columns)
#       6
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Build a Gaussian Mixture Model

# %%
import sys
import csv
import pandas as pd
import numpy as np
import sklearn.mixture as mixture
import sklearn.metrics as metrics
import matplotlib.pyplot as plt

DATA_DIR  = '../data/'
DATA_FILE = 'house-prices.csv'
PLOTS_DIR = '../plots/'

ENCODE_BRICK = { 'No' : 0 , 'Yes' : 1 }
ENCODE_HOOD  = { 'East' : 0, 'North' : 90, 'West' : 180, 'South' : 270 }

try:
    df = pd.read_csv(DATA_DIR+DATA_FILE,na_filter=False)
except IOError as iox:
    print('there was an I/O error trying to open the data file: ' + str( iox ))
    sys.exit()
    
M = len(df.values)
N = len(df.columns)

X = np.zeros((M,2))

for i in range(M):
    X[i][0] = df['Price'][i]
    X[i][1] = df['SqFt'][i]

plt.figure()
plt.plot(X[:,0],X[:,1],'bo')
# plt.scatter( X[:,0], X[:,1], 0.8 )
plt.xlabel("Price")
plt.ylabel("SqFt",fontsize = 15)

# plt.show()
plt.close()

K =2
gmm = mixture.GaussianMixture(n_components= K , covariance_type='spherical')
gmm.fit(X)

#clusters 
labels = gmm.predict(X)

print('GMM parameters:')
for i in range(K):
    print('component {}:'.format( i ))
    #2 attributes
    for j in range(2):
        print('attribute {}, mean={}'.format(j,gmm.means_[i][j] ))
    print()
    
#-compute and print log-likelihood score
print('log-likelihood score=' + str( gmm.score( X ) ))

# define markers for up to 10 clusters
CLUSTER_MARKERS = [ 'bo', 'rv', 'c^', 'm<', 'y>', 'ks', 'bp', 'r*', 'cD', 'mP' ]
plt.figure()
plt.scatter( X[:,0], X[:,1], 0.8 )
plt.xlabel( 'Price' )
plt.ylabel( 'SqFt' )
plt.plot(gmm.means_[0][0],gmm.means_[0][1],CLUSTER_MARKERS[0],markersize = 10)
plt.plot(gmm.means_[1][0],gmm.means_[1][1],CLUSTER_MARKERS[1],markersize = 10)
for i in range(M):
    plt.plot(X[i][0],X[i][1],CLUSTER_MARKERS[labels[i]],alpha = 0.3, markersize = 5)
plt.show()
plt.close()

ll_score = []
sc_score = []
ch_score = []
for K in range(2,10):
    gmm = mixture.GaussianMixture(n_components= K ,covariance_type="spherical")
    gmm.fit(X)
    
    labels = gmm.predict(X)
    
    ll_score.append(round(gmm.score(X),2) )
    sc_score.append(round(metrics.silhouette_score(X,labels, metric = 'euclidean' ),4)) 
    ch_score.append(round(metrics.calinski_harabasz_score(X,labels),2))
    
    plt.figure()
    plt.scatter( X[:,0], X[:,1], 0.8 )
    plt.title("K = " + str(K))
    plt.xlabel( 'Price' )
    plt.ylabel( 'SqFt' )
    for k in range(K):
        plt.plot(gmm.means_[k][0],gmm.means_[k][1],CLUSTER_MARKERS[k],markersize= 10)
    for i in range(M):
        plt.plot(X[i][0],X[i][1],CLUSTER_MARKERS[labels[i]],alpha = 0.5,markersize = 5)
    plt.show()
    plt.close()
score_dic = {"log-likelihood":ll_score, "silhouette":sc_score,"calinski-harabasz":ch_score}
index_ = [i for i in range(2,10)]
df = pd.DataFrame.from_dict(score_dic)
df.index = index_
df
# Out:
# GMM parameters:
# component 0:
# attribute 0, mean=111950.76812905156
# attribute 1, mean=1917.2750828425044
#
# component 1:
# attribute 0, mean=156374.17040881055
# attribute 1, mean=2118.42540903556
#
# log-likelihood score=-21.982538466058983
#    log-likelihood  silhouette  calinski-harabasz
# 2          -21.98      0.6057             272.84
# 3          -21.72      0.4904             216.16
# 4          -21.37      0.5317             355.31
# 5          -21.07      0.5354             382.71
# 6          -20.96      0.5411             463.72
# 7          -20.68      0.5338             497.87
# 8          -20.55      0.5196             504.28
# 9          -20.44      0.5447             602.85
